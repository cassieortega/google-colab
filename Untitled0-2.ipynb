# %%
import matplotlib.pyplot as plt

# %%
VIS1_MEAN = 443
VIS2_MEAN = 395.5
VIS1_STD = 88.48100863
VIS2_STD = 93.19781829

# %%
# build a bar plot
plt.bar(['Person 1 Visual', 'Person 1 Auditory'],[VIS1_MEAN, VIS2_MEAN], yerr=[VIS1_STD, VIS2_STD], capsize=10)
plt.ylabel('Speed (msec)')
plt.xlabel("Reflex Type")
plt.title('Reflex Speed, Visual vs. Auditory')
# Out:
# Text(0.5, 1.0, 'Reflex Speed, Visual vs. Auditory')
